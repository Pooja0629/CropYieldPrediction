# %%
import pandas as pd

df = pd.read_csv("crop_yield.csv")
df.head()
# Out:
# C:\Users\Dell\pandas.py:3: SyntaxWarning: invalid escape sequence '\p'
#   df = pd.read_csv('D:\pooja emails.csv')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       3 df = pd.read_csv("crop_yield.csv")
#       4 df.head()
#
# File ~\pandas.py:3
#       1 import pandas as pd
# ----> 3 df = pd.read_csv('D:\pooja emails.csv')
#       4 print(df.head())
#
# AttributeError: module 'pandas' has no attribute 'read_csv' (consider renaming 'C:\Users\Dell\pandas.py' if it has the same name as a library you intended to import)
